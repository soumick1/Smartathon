# %%
import matplotlib.pyplot as plt
import cv2
from utilities.canny import canny
from utilities.laplacian import laplacian
from utilities.ostu_threholding import otsu_thresholding

# %%
img = cv2.imread("../imgs/Bedrock-Blogs-1100x500.png", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(canny(img))

# %%
plt.imshow(laplacian(img))

# %%
plt.imshow(otsu_thresholding(img))
